# %% [markdown]
# Лабораторная работа №1. Извлечение ключевых слов из текста.

# %% [markdown]
# В файле README.md лежат некоторые пояснения, ссылка на исходные ключевые слова, а также возможный ответ на 5 вопрос

# %% [markdown]
# Ниже представлены используемые библиотеки:

# %%
import pprint
import pandas as pd

from nlp_rake import Rake
from summa import keywords
from pymorphy2 import MorphAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %% [markdown]
# Зададим функции для предобработки текста:

# %%
def get_preload_text():
    """
    Запись предобработанного текста
    """
    for i in range(1, 5):
        with open(f"./packs/N{i}/text.txt", encoding='utf-8') as f:
            res_text = preload(f.read())
        with open(f"./packs/N{i}/res_text.txt", 'w', encoding='utf-8') as f:
            f.write(res_text)


def preload(text):
    """
    Предобработка текста (лемматизация)
    """

    punctuation_signs = list("?:!.,;")

    res = text.replace("\r", " ")
    res = text.replace("\n", " ")
    res = res.replace("    ", " ")
    res = res.replace('"', '')
    res = res.lower()
    for punct_sign in punctuation_signs:
        res = res.replace(punct_sign, '')
    sentences = [word_tokenize(i, language="russian") for i
                 in sent_tokenize(res, language="russian")]

    # Приведем к нормальной форме
    morph = MorphAnalyzer()
    sentences = [[morph.parse(i)[0].normal_form for i in sen]
                 for sen in sentences]

    # Удалим стоп слова
    russian_stopwords = stopwords.words("russian")
    res_sentences = [[word for word in sen if word not in russian_stopwords]
                     for sen in sentences]

    # Соберем в кучу
    res_text = ' '.join(sentences[0])
    return res_text

# %% [markdown]
# Ниже определены функции, необходимые при методе Tf-Idf:

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)


def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """
    Определение ревелантных ключей
    :param feature_names:
    :param sorted_items:
    :param topn:            количество
    :return:                словарь с ключами и значениями - частотой
    """
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]

    return results

# %% [markdown]
# Определим класс, с помощью которого мы будем выделять ключевые слова из текстов:

# %%
class Extraction:
    """
    Класс, описывающий работу поиска ключевых слов из текста
    """

    def __init__(self):
        # Массивы ключевых слов для текстов
        self.keywords = []              # Исходыне
        self.manual_keywords = []       # Составленные вручную
        self.textrank_keywords = []     # С методом TextRank
        self.tfidf_keywords = []        # С методом TfIdf
        self.rake_keywords = []         # С методом RAKE

    def get_keywords(self):
        """
        Вычленение ключевых слов из файла
        """
        for i in range(1, 5):
            df = pd.read_csv(f"./packs/N{i}/keys.csv", sep='|')
            set_in = set()
            for row in df["lemm"].to_list():
                set_in.add(row)
            self.keywords.append(set_in)

    def manual_markup(self):
        """
        Создание объединенных множеств ключевых слов
        """
        for i in range(1, 5):
            df = pd.read_csv(f'./packs/keywords{i}.csv', sep='|')
            set_in = set()
            for row in df['tags'].to_list():
                set_in.add(row)
            res_words = set_in.intersection(self.keywords[i-1])
            self.manual_keywords.append(res_words)

    def textrank_extraction(self):
        """
        TextRank способ извлечения
        """
        for i in range(1, 5):
            with open(f"./packs/N{i}/res_text.txt", encoding='utf-8') as f:
                res_text = f.read()
            self.textrank_keywords.append(
                set(keywords.keywords(res_text, language='russian', split=True,
                                      additional_stopwords=stopwords.words("russian"))))

    def rake_extraction(self):
        """
        RAKE способ извлечения
        """
        for i in range(1, 5):
            with open(f"./packs/N{i}/res_text.txt", encoding='utf-8') as f:
                res_text = f.read()
                rake = Rake(language_code='ru', max_words=1)
                keywords = rake.apply(res_text)

                set_in = set()
                for i in keywords:
                    set_in.add(i[0])
                self.rake_keywords.append(set_in)

    def tfidf_extraction(self):
        """
        TfIdf способ извлечения
        """
        pass
        texts = []
        for i in range(1, 5):
            with open(f"./packs/N{i}/res_text.txt", encoding='utf-8') as f:
                texts.append(f.read())

        cv = CountVectorizer(max_df=0.85, stop_words=stopwords.words("russian"), max_features=150)
        word_count_vector = cv.fit_transform(texts)
        tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
        tfidf_transformer.fit(word_count_vector)

        feature_names = cv.get_feature_names_out()

        for doc in texts:
            tf_idf_vector = tfidf_transformer.transform(cv.transform([doc]))
            sorted_items = sort_coo(tf_idf_vector.tocoo())

            res = set()
            for key in extract_topn_from_vector(feature_names, sorted_items, 30):
                res.add(key)
            self.tfidf_keywords.append(res)

    def pprint(self):
        """
        Проверка введённых/извлеченных ключевых слов
        """
        pp = pprint.PrettyPrinter(compact=True)
        print('Keywords')
        pp.pprint(self.keywords)
        print('---------')
        print('Manual Keywords')
        pp.pprint(self.manual_keywords)
        print('---------')
        print('TextRank Keywords')
        pp.pprint(self.textrank_keywords)
        print('---------')
        print('TfIdf Keywords')
        pp.pprint(self.tfidf_keywords)
        print('---------')
        print('RAKE Keywords')
        pp.pprint(self.rake_keywords)

    def pprint_common(self):
        pp = pprint.PrettyPrinter(compact=True)
        print('---------')
        print('TextRank+TfIdf Keywords')
        common = [i.intersection(j) for i, j in zip(self.textrank_keywords,
                                                   self.tfidf_keywords)]
        pp.pprint(common)

        print('---------')
        print('TextRank+RAKE Keywords')
        common = [i.intersection(j) for i, j in zip(self.textrank_keywords,
                                                   self.rake_keywords)]
        pp.pprint(common)
        print('---------')
        print('TfIdf+RAKE Keywords')
        common = [i.intersection(j) for i, j in zip(self.tfidf_keywords,
                                                   self.rake_keywords)]
        pp.pprint(common)

# %% [markdown]
# Предобработаем тексты и найдём ключевые слова в тексте:

# %%
get_preload_text()

# Определим класс для работы
a = Extraction()

# Загрузим ключевые слова, которые были помечены, а так же сравним с нашими собственными
a.get_keywords()
a.manual_markup()

# Используем методы выделения ключевых слов
a.textrank_extraction()
a.rake_extraction()
a.tfidf_extraction()

# А теперь выпишем их
a.pprint()
# Out:
# Keywords
# [{'10 июля', '100 спутников', '20 отраслях', '200 действующих',
#   '2020-2025 годах', '2025 году', '30 искусственных', '307 запусков', '39 в',
#   'аппарат', 'год', 'китай', 'кнр', 'космический', 'марс', 'национальный', 'нс',
#   'пекин', 'прорыв', 'страна', 'тасс', 'технология', 'ци', 'юц'},
#  {'1', '1 миллиард', '1 трлн', '1,2 трлн', '10 годами', '111.4 указанного',
#   '12 суперкластеров', '14 млрд', '15-процентного', '2017 г', '2025 году',
#   '2030 году', '22 апреля 2019 года', '27 инновационно-территориальных',
#   '30 протокола', '4', '43 промышленных', '48 части 1 статьи 93 44-фз',
#   '600 организаций', '85 новых', 'аеа', 'ар', 'ас', 'баз', 'биокад',
#   'боеприпас', 'внешэкономбанк', 'внии', 'военнопромышленный', 'военный',
#   'возможность', 'восход', 'вп', 'вузы', 'высокотехнологичный', 'гоз',
#   'госзаказ', 'госкорпорация', 'государственный', 'государство', 'гпб',
#   'гражданский', 'группа', 'да', 'данный', 'двойной', 'дг', 'диверсификация',
#   'до', 'до 30%', 'до 50%', 'договор', 'дополнительный', 'допуск',
#   'евразийский', 'задача', 'заказчик', 'закон', 'закупка', 'запрет',
#   'заседание', 'зг', 'зигче', 'иб', 'или', 'инвестиционный', 'инвестиция',
#   'инновационный', 'иностранный', 'институт', 'использование', 'кгнц', 'кз',
#   'ки', 'кластер', 'кластерный', 'коллегия', 'комиссия', 'компетенция',
#   'комплекс', 'контракт', 'красноярский', 'ку', 'ма', 'максимальной',
#   'межведомственный', 'мера', 'механизм', 'москва', 'мр', 'мсп',
#   'муниципальные', 'муниципальный', 'назначение', 'научно-промышленный',
#   'национальный', 'необходимый', 'ниокр', 'нк', 'новое', 'новосибирский',
#   'новый', 'нужда', 'нцит', 'обеспечение', 'область', 'оборона', 'оборонный',
#   'оборудование', 'объем', 'объема', 'обязательство', 'ограничение', 'один',
#   'ок', 'ооо', 'опк', 'определение', 'организация', 'осуществление',
#   'от 04.06.2018 г', 'от 05.04.2013 г', 'от 05.12.2016 г', 'от 12.11.2016 г',
#   'от 2 до 5%', 'от 22.12.2016 г', 'от 29.05.2014 г', 'от 31 декабря 2014',
#   'от 31.01.2019 г', 'офсетный', 'перечень', 'пир', 'пко2', 'планирование',
#   'подход', 'порядок', 'поставка', 'поставщик', 'пп', 'пр', 'правительство',
#   'предельный', 'предприятие', 'представитель', 'преференциальный', 'программа',
#   'продукция', 'проект', 'проектный', 'производство', 'промышленность',
#   'промышленный', 'протокол', 'процесс', 'прф', 'пр№', 'работ', 'работа',
#   'рабочий', 'развитие', 'размещение', 'разработка', 'рамка', 'реализация',
#   'регион', 'региональный', 'регулирование', 'режим', 'результат', 'рм',
#   'роскосмос', 'россия', 'рф', 'рынок', 'рыночный', 'с 2019 г.системы', 'с.1',
#   'связанный', 'смм', 'создание', 'соответствие', 'сп', 'ср', 'срок', 'субъект',
#   'территория', 'техника', 'технология', 'товар', 'трансфер', 'управление',
#   'уровень', 'условие', 'услуг', 'услуга', 'установление', 'участие',
#   'участник', 'фгбу', 'фгбун', 'фгуп', 'федеральный', 'фипс', 'фн', 'фонд',
#   'формирование', 'фцп', 'цель', 'цена', 'центр', 'часть', 'число', 'экономика',
#   'эра', 'этп', '№1166', '№126н', '№1441', '№44-фз', '№488-фз', '№56',
#   '№бо-п22-првпк', '№дк-п9-18пр', '№о', '№пр-2346'},
#  {'1 июня 1988 г', '2 августа', '2 февраля', '20 октября 2018 года',
#   '2019-2020 годах', '3 июля', '31 июля', '4 декабря', '5 февраля', '60 дней',
#   '9м729', 'американский', 'вашингтон', 'вп', 'дальность', 'дб', 'договор',
#   'дрсмд', 'дт', 'европа', 'интерфакс', 'калибр', 'комплекс', 'ма', 'москва',
#   'мп', 'мр', 'наземный', 'ниокр', 'о1д5к', 'о5д1к', 'першингов', 'путин',
#   'ракета', 'россия', 'рсмд', 'рф', 'рябок', 'сз', 'система', 'ср', 'средний',
#   'сторона', 'сш', 'сша', 'установка'},
#  {'10 лет', '12 проектов', '1979 по 1987-й', '1992 года', '1996-1997-м',
#   '1997-2000-м', '25 лет', '6 августа 2019 года', '70 процентов',
#   '700 миллиардов', '793', '90-х', 'аиш', 'академия', 'альянс', 'аппарат',
#   'беб', 'безопасность', 'бережливый', 'важный', 'ввб', 'вдк', 'век', 'вм',
#   'возможность', 'впк', 'втчр', 'вымпел', 'главный', 'гомель',
#   'государственное', 'государственный', 'государство', 'достижение', 'дфу',
#   'епс', 'жв', 'завод', 'задача', 'зп', 'ис', 'кадровыми', 'китай', 'кластер',
#   'кнр', 'комплекс', 'материальными', 'мвту', 'министр', 'минпромторг',
#   'минфин', 'минэкономразвития', 'мировой', 'михайлов', 'множество',
#   'мультикластеры', 'наука', 'научный', 'национальный', 'наш', 'необходимость',
#   'нии', 'ниирп', 'нпо', 'нынешний', 'оборонка', 'опк', 'осмысленный',
#   'осуществление', 'отношение', 'платформа', 'подольск', 'политик', 'политика',
#   'последний', 'потенциал', 'предприятие', 'про', 'проблема', 'проект',
#   'производство', 'промышленность', 'промышленный', 'псп', 'радиозавод',
#   'развитие', 'ресурс', 'решение', 'российский', 'россия', 'рспп', 'рф',
#   'с 1969 по 1975-й', 'с 1975-го', 'с 1987-го', 'саз', 'система', 'сквозной',
#   'сккп', 'славский', 'снижение', 'совет', 'создание', 'спрн', 'срэ', 'ссср',
#   'степень', 'сторона', 'страна', 'сфера', 'счетный', 'сша', 'техника',
#   'технологический', 'технология', 'ткз', 'уровень', 'условие', 'устинова',
#   'финансовыми', 'хх', 'ххi', 'цб', 'циркулярный', 'цнпо', 'цэ', 'четверть',
#   'экология', 'экономика', 'экономический', '№30'}]
# ---------
# Manual Keywords
# [{'китай', 'аппарат', 'кнр', 'пекин', 'национальный', 'технология'},
#  {'контракт', 'кластер', 'продукция', 'организация', 'промышленный'},
#  {'ракета', 'сша', 'сторона', 'договор', 'россия', 'рф'},
#  {'государственный', 'наука', 'осуществление', 'страна', 'технологический',
#   'уровень', 'экономика'}]
# ---------
# TextRank Keywords
# [{'аппарат', 'благоприятный', 'год', 'департамент', 'интенсивный', 'китай',
#   'кнр юй', 'который', 'национальный космический управление', 'наш страна',
#   'около', 'программа', 'прорыв пекин', 'спутник', 'технология',
#   'характер одновременно', 'хозяйство', 'экология', 'это'},
#  {'база', 'возможный', 'выпускать', 'г', 'гоз', 'государственно',
#   'государственный', 'государство', 'гражданский', 'далее', 'данные', 'данный',
#   'дать', 'двойной назначение', 'деятельность', 'дополнительный', 'заказ',
#   'заказчик', 'закупка', 'заседание', 'иметь высокий', 'инвестиционный',
#   'инвестиция', 'инновационно', 'инновационный', 'инновация', 'иностранный',
#   'институт', 'кластер', 'кластерный', 'контракт', 'который',
#   'межведомственный', 'методический', 'механизм', 'мочь', 'научно', 'научный',
#   'национальный проект', 'необходимо', 'необходимость', 'необходимый', 'новый',
#   'номенклатура', 'нужда', 'обеспечение', 'обеспечить возможность',
#   'область развитие', 'оборона', 'оборонно', 'оборонный предприятие',
#   'оборудование', 'объём', 'опк', 'определение перспективный', 'определённый',
#   'организация', 'осуществлять', 'осуществляться', 'офсетный', 'подготовить',
#   'подход', 'позволить', 'показатель эффективность рост', 'понижать', 'порядок',
#   'поставщик', 'пп рф', 'правовой мера', 'представитель', 'программа',
#   'продукция', 'промышленность', 'промышленный', 'процентный', 'процесс',
#   'работа', 'рабочий', 'разработка', 'рамка', 'расширить перечень',
#   'реализация', 'регион', 'региональный', 'регулирование цена',
#   'российский федерация', 'россия', 'рынок высокотехнологичный товар',
#   'рыночный', 'связанный', 'связать', 'сегодня', 'система', 'системе',
#   'согласно', 'создание', 'срок', 'стать', 'статья', 'субъект', 'также',
#   'технологический', 'технология', 'указанный', 'уровень', 'условие допуск',
#   'устанавливать', 'устанавливаться', 'установить', 'установление',
#   'установленный', 'участник', 'фгуп', 'федеральный', 'формирование', 'целое',
#   'цель задача', 'центр', 'часто', 'часть', 'экономический', 'эффективный',
#   'являться диверсификация производство путём'},
#  {'американский', 'выйти', 'год', 'день', 'дрсмд договор', 'заявить',
#   'июль интерфакс', 'который', 'лётный', 'месяц', 'нарушать', 'наш',
#   'новый ракетный система средний дальность наземный', 'осень', 'относительно',
#   'президент', 'путин', 'ракета', 'россия', 'рф', 'собственный ниокр москва',
#   'сторона', 'сша', 'февраль'},
#  {'адекватно', 'адекватный', 'активно', 'активный', 'безопасность', 'бизнес',
#   'важно', 'василиевич', 'век', 'возможность', 'вопрос', 'выбор', 'вывод',
#   'высокий', 'главное', 'главный', 'глубокий', 'государственно',
#   'государственный', 'государство способный', 'дальнейший', 'двенадцать',
#   'дефицит', 'директор', 'долговой', 'достижение', 'жизнь', 'задача',
#   'заместитель', 'идти', 'иметь', 'иметься', 'интерес', 'инфраструктура',
#   'использование', 'исследование', 'й', 'качество', 'китай', 'компания',
#   'концентрация', 'кредитно отношение стать',
#   'кредитный ресурс утрата конкурентный', 'критически важный',
#   'ликвидировать новый', 'лишиться', 'лишь', 'масштабный', 'мера ясно',
#   'министерство', 'министр оборона', 'мировой', 'многий год вместо', 'многое',
#   'множество', 'направление', 'направленность', 'наука', 'научно комплекс',
#   'национальный', 'наш', 'невольно', 'необходимость оценка', 'необходимый',
#   'николай', 'нынешний депрессия', 'обеспечивать', 'обеспечиваться', 'оборонно',
#   'опасность', 'орден трудовой красный', 'основной', 'основный',
#   'осуществление', 'осуществлять', 'осуществляться', 'повышение', 'позволить',
#   'показатель', 'получить', 'построить', 'потенциал', 'правительство',
#   'превращение', 'прежний', 'принцип оптимизация', 'причина весь', 'проблема',
#   'проект', 'производство', 'промышленность', 'промышленный политика',
#   'процесс', 'путь', 'развитие', 'размывание', 'разработка',
#   'решение который невозможно', 'российский опк', 'рф', 'рынок', 'рыночный',
#   'сегодня', 'сектор', 'системность', 'системный',
#   'славский оборонный предприятие', 'снижение', 'современный россия',
#   'создание', 'создать', 'сотня', 'способность', 'старый', 'степень', 'сторона',
#   'страна', 'структура', 'технологический', 'технология', 'уровень', 'усилие',
#   'условие', 'устаревание', 'устинов', 'утратить', 'финансовый', 'хотеться',
#   'целевой', 'чрезвычайно опасный тенденция', 'экономика', 'экономический',
#   'это свой научный', 'эффективность система', 'ясный'}]
# ---------
# TfIdf Keywords
# [{'весь', 'заместитель', 'иметь', 'исследование', 'китай', 'кнр', 'космический',
#   'научный', 'национальный', 'область', 'основа', 'особый', 'отношение',
#   'перечень', 'последний', 'программа', 'развитие', 'разработка', 'ресурс',
#   'страна', 'сфера', 'также', 'технология', 'управление', 'условие', 'число',
#   'экономика'},
#  {'государственный', 'гражданский', 'двойной', 'диверсификация', 'допуск',
#   'закупка', 'иностранный', 'кластер', 'контракт', 'назначение', 'научно',
#   'обеспечение', 'оборонный', 'опк', 'организация', 'офсетный', 'поставщик',
#   'пп', 'предприятие', 'продукция', 'производство', 'промышленный', 'развитие',
#   'реализация', 'российский', 'россия', 'рф', 'товар', 'федерация', 'цена'},
#  {'вопрос', 'дальность', 'договор', 'комплекс', 'министр', 'мочь', 'научно',
#   'новый', 'оборона', 'президент', 'процесс', 'ракета', 'результат', 'решение',
#   'российский', 'россия', 'рф', 'свой', 'система', 'срок', 'сторона', 'сша',
#   'также', 'участие'},
#  {'важный', 'век', 'государственный', 'государство', 'задача', 'лишь', 'наука',
#   'научно', 'научный', 'необходимость', 'опк', 'осуществление', 'политика',
#   'потенциал', 'предприятие', 'проблема', 'проект', 'производство',
#   'промышленность', 'промышленный', 'развитие', 'решение', 'система', 'стать',
#   'страна', 'технологический', 'технология', 'уровень', 'экономика',
#   'экономический'}]
# ---------
# RAKE Keywords
# [{'2020-2025', '2025', 'аппарат', 'географический', 'иметься', 'марс', 'орбита',
#   'отношение', 'отрасль', 'последний', 'прошлый', 'состояться', 'страна',
#   'текущий', 'треть', 'экономика'},
#  {'04062018', '05042013', '05122016', '12112016', '2017', '2019', '2025',
#   '2030', '22122016', '29052014', '31012019', 'биокад', 'бочкарёв', 'вместе',
#   'внешэкономбанк', 'восход', 'вывод', 'выход', 'гоз', 'госкомпания',
#   'госкорпорация', 'государственный', 'госучастие', 'далее', 'деталь',
#   'дополнение', 'заключить', 'закрепить', 'исследование', 'катетер',
#   'количество', 'компания', 'контракт', 'крупный', 'максимальный', 'малое',
#   'межрегиональный', 'мера', 'механизм', 'модернизация', 'модернизироваться',
#   'москва', 'муниципальный', 'направить', 'научно-образовательный', 'начальный',
#   'обеспечение', 'объём', 'опк', 'осваиваться', 'особенность', 'осуществляться',
#   'отношение', 'оцениваться', 'оценка', 'первоочередной', 'перевод', 'пир',
#   'поручить', 'правило', 'претендовать', 'применить', 'происходить', 'размер',
#   'разработать', 'разработка', 'ран', 'регион', 'региональный', 'регулирование',
#   'роскосмос', 'связанный', 'согласно', 'создаваться', 'создание',
#   'соответствие', 'способствовать', 'страна', 'считать', 'так-же', 'тема',
#   'течение', 'требование', 'уровень', 'услуга', 'устанавливать', 'участие',
#   'фгб', 'фгбуна', 'фгуп', 'функционирование', 'фцп', 'цель', 'число', 'шаг',
#   'эра'},
#  {'1000', '2019-2020', '500', 'вернуться', 'вопрос', 'выступление', 'договор',
#   'дрсмд', 'европа', 'замминистра', 'касаться', 'линия', 'месяц', 'ожидать',
#   'ответ', 'относительно', 'разразиться', 'рассчитывать', 'россия', 'связь',
#   'система', 'совершенно', 'создать', 'сша', 'уничтожить', 'утверждать'},
#  {'1969', '1975-го', '1975-й', '1979', '1987-го', '1987-й', '1996–1997-м',
#   '1997–2000-м', '793', 'банк', 'безопасность', 'борьба', 'важно', 'вовлечение',
#   'возможность', 'вопрос', 'вспомогательный', 'встроить', 'выдвигать',
#   'главное', 'говорить', 'гомель', 'государственный', 'гражданин',
#   'действительность', 'деньга', 'департамент', 'депрессия', 'должность',
#   'достижение', 'доступ', 'забалтывания', 'завершить', 'заметить', 'западный',
#   'знание', 'инновация', 'исполнение', 'итог', 'кнр', 'контракт', 'критически',
#   'ликвидировать', 'мера', 'место', 'минпромторг', 'многий', 'многое',
#   'многократно', 'надежда', 'наполовину', 'направить', 'напротив', 'наука',
#   'научный', 'находиться', 'нацпроект', 'начальник', 'недавний',
#   'необходимость', 'ниирп', 'нынешний', 'оборонка', 'общество', 'опк',
#   'осуществление', 'отрасль', 'отставание', 'первостепенный', 'перелом',
#   'перенос', 'план', 'поддержание', 'поддержка', 'подольск', 'подход',
#   'показатель', 'понимание', 'последний', 'постановка', 'предшественник',
#   'принять', 'проблема', 'программа', 'продвижение', 'проект', 'производство',
#   'промышленность', 'работа', 'реализация', 'решение', 'самореализация',
#   'свойство', 'связь', 'сконцентрировать', 'следовать', 'следствие', 'слово',
#   'создание', 'создать', 'сосредоточиться', 'справка', 'станкостроение',
#   'становиться', 'стать', 'страна', 'счёт', 'сша', 'техника', 'технология',
#   'треть', 'три-четыре', 'угроза', 'удивительный', 'федеральный', 'фон',
#   'форма', 'характер', 'хороший', 'ххi', 'целое', 'цель', 'частность', 'ясно',
#   'ясность'}]
